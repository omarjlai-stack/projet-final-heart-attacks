# %%
import pandas as pd
import numpy as np
data=pd.read_csv('C://Users//asus//Downloads//heart attack.csv',encoding = "ISO-8859-1")
datadata.isnull().sum()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
#no missing values

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.title("histogram of ages")
plt.xlabel("age")
data['age'].plot.hist()

# %%
#the most common age is around 60 to 65
#the least common age is around 30

# %%
plt.title("histogram of sex")
plt.xlabel("sex")
data['sex'].plot.hist()

# %%
#the least common sex is 0
#the most common sex is 1

# %%
g=sns.FacetGrid(data,col='target')

g.map(plt.hist,'age',bins=20)

# %%
#having the disease is more common at age 40 to 50
#having the disease is less common at age 50 to 60

# %%
g=sns.FacetGrid(data,col='target')

g.map(plt.hist,'sex',bins=20)

# %%
#having the disease is more common in sex 1
#having the disease is less common in sex 0

# %%
def plot_correlation_map( data ):

    corr = data.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )
plot_correlation_map( data )

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
from sklearn.metrics import classification_report

# %%
x=data[["age","sex","cp","trestbps","chol","fbs","restecg","thalach","exang","oldpeak","slope","ca","thal"]]
y=data["target"]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.35,random_state=40)

# %%
logreg = LogisticRegression()   
logreg.fit(x_train, y_train)  
y_pred  = logreg.predict(x_test)
# Out:
# C:\Users\asus\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)

# %%
print("Accuracy={:.2f}".format(logreg.score(x_test, y_test)))
# Out:
# Accuracy=0.88

# %%
confusion_matrix=pd.crosstab(y_test,y_pred,rownames=['actual'],colnames=['perdicted'])
print(confusion_matrix)
# Out:
# perdicted   0   1
# actual
# 0          41   9
# 1           4  53

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.82      0.86        50
#            1       0.85      0.93      0.89        57
#
#     accuracy                           0.88       107
#    macro avg       0.88      0.87      0.88       107
# weighted avg       0.88      0.88      0.88       107

# %%
#the results are somehow good
